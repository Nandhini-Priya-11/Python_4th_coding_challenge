# %%
## Create variables to store the student’s name, age, and their favourite subjects they are enrolled in.Display the student’s information in a user-friendly format. Display the updated list of subjects.

# %%
Student_name = input("")
Age = input("")
Subject =['Maths', 'Chemistry']

print(f"Student_name {Student_name},Age{Age},Subject{Subject}")
# Out:
# NP
# 17
# Student_name NP,Age17,Subject['Maths', 'Chemistry']

# %%
Subject.append('English')

print(Subject)
# Out:
# ['Maths', 'Chemistry', 'English']
