# %%
## Ask the user to input a sentence (representing feedback).

# %%
Feedback = input()
# Out:
# Data science is the future trend  Data is working everywhere.

# %%
print(Feedback)
# Out:
# Data science is the future trend  Data is working everywhere.

# %%
## Count how many words are in the sentence.

# %%
Feedback ="Data science is the future trend, Data is working everywhere"

Words= Feedback.split()

print(len(Words))
# Out:
# 10

# %%
## Check how many times the word “data” appears in the sentence, regardless of case.

# %%
Feedback ="Data science is the future trend, Data is working everywhere"

Feedback.lower()
# Out:
# 'data science is the future trend, data is working everywhere'

# %%
print(Feedback)
# Out:
# Data science is the future trend, Data is working everywhere

# %%
Feedback.count("Data")
# Out:
# 2

# %%
## Extract and print the first 5 and last 5 characters of the feedback separately.

# %%
Feedback[0:6:1]
# Out:
# 'Data s'

# %%
Feedback[-5:]
# Out:
# 'where'

# %%
## Reverse the sentence and print it.

# %%
Feedback ="Data science is the future trend, Data is working everywhere"

Feedback[::-1]
# Out:
# 'erehwyreve gnikrow si ataD ,dnert erutuf eht si ecneics ataD'
